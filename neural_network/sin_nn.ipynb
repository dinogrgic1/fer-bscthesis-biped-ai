# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Activation
from keras.layers import Dense
from keras.callbacks import ModelCheckpoint
from numpy import asarray
import matplotlib.pyplot as plt

# %%
GRAPH_DATA = '../data/hoap2/walk.csv'

RLEG1_JOINT = 0
RLEG2_JOINT = 1
RLEG3_JOINT = 2
RLEG4_JOINT = 3
RLEG5_JOINT = 4
RLEG6_JOINT = 5
RARM1_JOINT = 6
RARM2_JOINT = 7
RARM3_JOINT = 8
RARM4_JOINT = 9

LLEG1_JOINT = 10
LLEG2_JOINT = 11
LLEG3_JOINT = 12
LLEG4_JOINT = 13
LLEG5_JOINT = 14
LLEG6_JOINT = 15
LARM1_JOINT = 16
LARM2_JOINT = 17
LARM3_JOINT = 18
LARM4_JOINT = 19

BODY_JOINT = 20

rleg1_angle = []
rleg2_angle = []
rleg3_angle = []
rleg4_angle = []
rleg5_angle = []
rleg6_angle = []

rarm1_angle = []
rarm2_angle = []
rarm3_angle = []
rarm4_angle = []

lleg1_angle = []
lleg2_angle = []
lleg3_angle = []
lleg4_angle = []
lleg5_angle = []
lleg6_angle = []

larm1_angle = []
larm2_angle = []
larm3_angle = []
larm4_angle = []
body_angle = []


if __name__ == '__main__':
    with open(GRAPH_DATA) as f:
        lines = f.readlines()
        for entry in lines:
            e = entry.split(',')
            rleg1_angle.append(int(e[RLEG1_JOINT]))
            rleg2_angle.append(int(e[RLEG2_JOINT]))
            rleg3_angle.append(int(e[RLEG3_JOINT]))
            rleg4_angle.append(int(e[RLEG4_JOINT]))
            rleg5_angle.append(int(e[RLEG5_JOINT]))
            rleg6_angle.append(int(e[RLEG6_JOINT]))
            
            rarm1_angle.append(int(e[RARM1_JOINT]))
            rarm2_angle.append(int(e[RARM2_JOINT]))
            rarm3_angle.append(int(e[RARM3_JOINT]))
            rarm4_angle.append(int(e[RARM4_JOINT]))

            lleg1_angle.append(int(e[LLEG1_JOINT]))
            lleg2_angle.append(int(e[LLEG2_JOINT]))
            lleg3_angle.append(int(e[LLEG3_JOINT]))
            lleg4_angle.append(int(e[LLEG4_JOINT]))
            lleg5_angle.append(int(e[LLEG5_JOINT]))
            lleg6_angle.append(int(e[LLEG6_JOINT]))
            
            larm1_angle.append(int(e[LARM1_JOINT]))
            larm2_angle.append(int(e[LARM2_JOINT]))
            larm3_angle.append(int(e[LARM3_JOINT]))
            larm4_angle.append(int(e[LARM4_JOINT]))
            body_angle.append(int(e[BODY_JOINT]))

# %%
    x = asarray([i for i in range(0,len(rleg4_angle))])
    y = asarray(rleg4_angle)
    
    x = x.reshape((len(x), 1))
    y = y.reshape((len(y), 1))

    scale_x = MinMaxScaler()
    x = scale_x.fit_transform(x)
    scale_y = MinMaxScaler()
    y = scale_y.fit_transform(y)
    print(x.min(), x.max(), y.min(), y.max())

model = Sequential([
    Dense(150, input_shape=(1,)),
    Activation('sigmoid'),
    Dense(50),
    Activation('sigmoid'),
    Dense(25),
    Activation('sigmoid'),
    Dense(25),
    Activation('sigmoid'),
    Dense(1)
])
# Out:
# 0.0 1.0 0.0 1.0

# %%
  filepath = "models/rleg4/rleg4-saved-model-{epoch:02d}"
  checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=False, mode='auto', period=50)
  callback_list = [checkpoint]
  model.compile(loss='mse', optimizer='adam')
  history = model.fit(x, y, epochs=500, batch_size=10, verbose=2, callbacks=callback_list)
# Out:
# Epoch 108/500
# 1028/1028 - 1s - loss: 3.3447e-04
# Epoch 109/500
# 1028/1028 - 1s - loss: 2.8791e-04
# Epoch 110/500
# 1028/1028 - 1s - loss: 3.7337e-04
# Epoch 111/500
# 1028/1028 - 1s - loss: 3.3822e-04
# Epoch 112/500
# 1028/1028 - 1s - loss: 2.8546e-04
# Epoch 113/500
# 1028/1028 - 1s - loss: 3.4348e-04
# Epoch 114/500
# 1028/1028 - 1s - loss: 3.7123e-04
# Epoch 115/500
# 1028/1028 - 1s - loss: 2.8432e-04
# Epoch 116/500
# 1028/1028 - 1s - loss: 3.2212e-04
# Epoch 117/500
# 1028/1028 - 1s - loss: 2.8556e-04
# Epoch 118/500
# 1028/1028 - 1s - loss: 3.0584e-04
# Epoch 119/500
# 1028/1028 - 1s - loss: 3.0523e-04
# Epoch 120/500
# 1028/1028 - 1s - loss: 2.9806e-04
# Epoch 121/500
# 1028/1028 - 1s - loss: 2.8511e-04
# Epoch 122/500
# 1028/1028 - 1s - loss: 2.8452e-04
# Epoch 123/500
# 1028/1028 - 1s - loss: 2.4849e-04
# Epoch 124/500
# 1028/1028 - 1s - loss: 2.6760e-04
# Epoch 125/500
# 1028/1028 - 1s - loss: 3.0365e-04
# Epoch 126/500
# 1028/1028 - 1s - loss: 2.5389e-04
# Epoch 127/500
# 1028/1028 - 1s - loss: 3.3452e-04
# Epoch 128/500
# 1028/1028 - 1s - loss: 2.4994e-04
# Epoch 129/500
# 1028/1028 - 1s - loss: 2.5932e-04
# Epoch 130/500
# 1028/1028 - 1s - loss: 2.6644e-04
# Epoch 131/500
# 1028/1028 - 1s - loss: 2.7097e-04
# Epoch 132/500
# 1028/1028 - 1s - loss: 2.5115e-04
# Epoch 133/500
# 1028/1028 - 1s - loss: 2.6742e-04
# Epoch 134/500
# 1028/1028 - 1s - loss: 2.6353e-04
# Epoch 135/500
# 1028/1028 - 1s - loss: 2.5271e-04
# Epoch 136/500
# 1028/1028 - 1s - loss: 2.9946e-04
# Epoch 137/500
# 1028/1028 - 1s - loss: 2.6236e-04
# Epoch 138/500
# 1028/1028 - 1s - loss: 2.4389e-04
# Epoch 139/500
# 1028/1028 - 1s - loss: 2.6898e-04
# Epoch 140/500
# 1028/1028 - 1s - loss: 2.3953e-04
# Epoch 141/500
# 1028/1028 - 1s - loss: 2.6759e-04
# Epoch 142/500
# 1028/1028 - 1s - loss: 2.3813e-04
# Epoch 143/500
# 1028/1028 - 1s - loss: 3.3762e-04
# Epoch 144/500
# 1028/1028 - 1s - loss: 2.1209e-04
# Epoch 145/500
# 1028/1028 - 1s - loss: 2.5810e-04
# Epoch 146/500
# 1028/1028 - 1s - loss: 1.8603e-04
# Epoch 147/500
# 1028/1028 - 1s - loss: 2.1143e-04
# Epoch 148/500
# 1028/1028 - 1s - loss: 2.3552e-04
# Epoch 149/500
# 1028/1028 - 1s - loss: 2.2578e-04
# Epoch 150/500
# 1028/1028 - 1s - loss: 2.2925e-04
#
# Epoch 00150: saving model to models/rleg4/rleg4-saved-model-150
# INFO:tensorflow:Assets written to: models/rleg4/rleg4-saved-model-150/assets
# Epoch 151/500
# 1028/1028 - 1s - loss: 2.1176e-04
# Epoch 152/500
# 1028/1028 - 1s - loss: 2.0120e-04
# Epoch 153/500
# 1028/1028 - 1s - loss: 2.2351e-04
# Epoch 154/500
# 1028/1028 - 1s - loss: 2.4860e-04
# Epoch 155/500
# 1028/1028 - 1s - loss: 2.1766e-04
# Epoch 156/500
# 1028/1028 - 1s - loss: 2.5134e-04
# Epoch 157/500
# 1028/1028 - 1s - loss: 2.4492e-04
# Epoch 158/500
# 1028/1028 - 1s - loss: 2.4913e-04
# Epoch 159/500
# 1028/1028 - 1s - loss: 2.3573e-04
# Epoch 160/500
# 1028/1028 - 1s - loss: 2.5032e-04
# Epoch 161/500
# 1028/1028 - 1s - loss: 2.0804e-04
# Epoch 162/500
# 1028/1028 - 1s - loss: 1.9969e-04
# Epoch 163/500
# 1028/1028 - 1s - loss: 2.0120e-04
# Epoch 164/500
# 1028/1028 - 1s - loss: 2.1041e-04
# Epoch 165/500
# 1028/1028 - 1s - loss: 2.3533e-04
# Epoch 166/500
# 1028/1028 - 1s - loss: 2.2267e-04
# Epoch 167/500
# 1028/1028 - 1s - loss: 2.3424e-04
# Epoch 168/500
# 1028/1028 - 1s - loss: 1.7558e-04
# Epoch 169/500
# 1028/1028 - 1s - loss: 2.3959e-04
# Epoch 170/500
# 1028/1028 - 1s - loss: 1.8552e-04
# Epoch 171/500
# 1028/1028 - 1s - loss: 2.1277e-04
# Epoch 172/500
# 1028/1028 - 1s - loss: 2.2713e-04
# Epoch 173/500
# 1028/1028 - 1s - loss: 2.1941e-04
# Epoch 174/500
# 1028/1028 - 1s - loss: 2.0992e-04
# Epoch 175/500
# 1028/1028 - 1s - loss: 2.0700e-04
# Epoch 176/500
# 1028/1028 - 1s - loss: 2.5257e-04
# Epoch 177/500
# 1028/1028 - 1s - loss: 2.1045e-04
# Epoch 178/500
# 1028/1028 - 1s - loss: 2.1862e-04
# Epoch 179/500
# 1028/1028 - 1s - loss: 2.1649e-04
# Epoch 180/500
# 1028/1028 - 1s - loss: 1.9802e-04
# Epoch 181/500
# 1028/1028 - 1s - loss: 3.0005e-04
# Epoch 182/500
# 1028/1028 - 1s - loss: 2.1858e-04
# Epoch 183/500
# 1028/1028 - 1s - loss: 2.2326e-04
# Epoch 184/500
# 1028/1028 - 1s - loss: 1.7949e-04
# Epoch 185/500
# 1028/1028 - 1s - loss: 1.8453e-04
# Epoch 186/500
# 1028/1028 - 1s - loss: 1.9270e-04
# Epoch 187/500
# 1028/1028 - 1s - loss: 2.0625e-04
# Epoch 188/500
# 1028/1028 - 1s - loss: 1.9181e-04
# Epoch 189/500
# 1028/1028 - 1s - loss: 1.9907e-04
# Epoch 190/500
# 1028/1028 - 1s - loss: 1.7831e-04
# Epoch 191/500
# 1028/1028 - 1s - loss: 2.2136e-04
# Epoch 192/500
# 1028/1028 - 1s - loss: 1.7242e-04
# Epoch 193/500
# 1028/1028 - 1s - loss: 2.0212e-04
# Epoch 194/500
# 1028/1028 - 1s - loss: 1.7315e-04
# Epoch 195/500
# 1028/1028 - 1s - loss: 2.7468e-04
# Epoch 196/500
# 1028/1028 - 1s - loss: 1.6172e-04
# Epoch 197/500
# 1028/1028 - 1s - loss: 1.7856e-04
# Epoch 198/500
# 1028/1028 - 1s - loss: 2.0910e-04
# Epoch 199/500
# 1028/1028 - 1s - loss: 1.7580e-04
# Epoch 200/500
# 1028/1028 - 1s - loss: 2.3950e-04
#
# Epoch 00200: saving model to models/rleg4/rleg4-saved-model-200
# INFO:tensorflow:Assets written to: models/rleg4/rleg4-saved-model-200/assets
# Epoch 201/500
# 1028/1028 - 1s - loss: 1.6244e-04
# Epoch 202/500
# 1028/1028 - 1s - loss: 1.7558e-04
# Epoch 203/500
# 1028/1028 - 1s - loss: 2.0648e-04
# Epoch 204/500
# 1028/1028 - 1s - loss: 2.1578e-04
# Epoch 205/500
# 1028/1028 - 1s - loss: 1.9505e-04
# Epoch 206/500
# 1028/1028 - 1s - loss: 1.8763e-04
# Epoch 207/500
# 1028/1028 - 1s - loss: 1.8145e-04
# Epoch 208/500
# 1028/1028 - 1s - loss: 1.6784e-04
# Epoch 209/500
# 1028/1028 - 1s - loss: 2.1321e-04
# Epoch 210/500
# 1028/1028 - 1s - loss: 2.1629e-04
# Epoch 211/500
# 1028/1028 - 1s - loss: 1.5554e-04
# Epoch 212/500
# 1028/1028 - 1s - loss: 1.7953e-04
# Epoch 213/500
# 1028/1028 - 1s - loss: 1.7642e-04
# Epoch 214/500
# 1028/1028 - 1s - loss: 1.8881e-04
# Epoch 215/500
# 1028/1028 - 1s - loss: 2.0852e-04
# Epoch 216/500
# 1028/1028 - 1s - loss: 1.6877e-04
# Epoch 217/500
# 1028/1028 - 1s - loss: 1.5910e-04
# Epoch 218/500
# 1028/1028 - 1s - loss: 1.6094e-04
# Epoch 219/500
# 1028/1028 - 1s - loss: 1.7171e-04
# Epoch 220/500
# 1028/1028 - 1s - loss: 1.9360e-04
# Epoch 221/500
# 1028/1028 - 1s - loss: 1.9032e-04
# Epoch 222/500
# 1028/1028 - 1s - loss: 1.6066e-04
# Epoch 223/500
# 1028/1028 - 1s - loss: 1.8346e-04
# Epoch 224/500
# 1028/1028 - 1s - loss: 1.4690e-04
# Epoch 225/500
# 1028/1028 - 1s - loss: 1.8164e-04
# Epoch 226/500
# 1028/1028 - 1s - loss: 1.8131e-04
# Epoch 227/500
# 1028/1028 - 1s - loss: 1.5875e-04
# Epoch 228/500
# 1028/1028 - 1s - loss: 1.8483e-04
# Epoch 229/500
# 1028/1028 - 1s - loss: 1.6200e-04
# Epoch 230/500
# 1028/1028 - 1s - loss: 1.6130e-04
# Epoch 231/500
# 1028/1028 - 1s - loss: 1.6161e-04
# Epoch 232/500
# 1028/1028 - 1s - loss: 1.7844e-04
# Epoch 233/500
# 1028/1028 - 1s - loss: 1.9392e-04
# Epoch 234/500
# 1028/1028 - 1s - loss: 1.5875e-04
# Epoch 235/500
# 1028/1028 - 1s - loss: 1.9393e-04
# Epoch 236/500
# 1028/1028 - 1s - loss: 1.6262e-04
# Epoch 237/500
# 1028/1028 - 1s - loss: 1.6441e-04
# Epoch 238/500
# 1028/1028 - 1s - loss: 1.7122e-04
# Epoch 239/500
# 1028/1028 - 1s - loss: 1.4906e-04
# Epoch 240/500
# 1028/1028 - 1s - loss: 1.8637e-04
# Epoch 241/500
# 1028/1028 - 1s - loss: 1.6625e-04
# Epoch 242/500
# 1028/1028 - 1s - loss: 1.5194e-04
# Epoch 243/500
# 1028/1028 - 1s - loss: 1.8170e-04
# Epoch 244/500
# 1028/1028 - 1s - loss: 1.5506e-04
# Epoch 245/500
# 1028/1028 - 1s - loss: 1.4560e-04
# Epoch 246/500
# 1028/1028 - 1s - loss: 1.6979e-04
# Epoch 247/500
# 1028/1028 - 1s - loss: 1.8093e-04
# Epoch 248/500
# 1028/1028 - 1s - loss: 1.5953e-04
# Epoch 249/500
# 1028/1028 - 1s - loss: 1.6272e-04
# Epoch 250/500
# 1028/1028 - 1s - loss: 1.5037e-04
#
# Epoch 00250: saving model to models/rleg4/rleg4-saved-model-250
# INFO:tensorflow:Assets written to: models/rleg4/rleg4-saved-model-250/assets
# Epoch 251/500
# 1028/1028 - 1s - loss: 2.0037e-04
# Epoch 252/500
# 1028/1028 - 1s - loss: 1.6379e-04
# Epoch 253/500
# 1028/1028 - 1s - loss: 1.3614e-04
# Epoch 254/500
# 1028/1028 - 1s - loss: 1.7918e-04
# Epoch 255/500
# 1028/1028 - 1s - loss: 1.5096e-04
# Epoch 256/500
# 1028/1028 - 1s - loss: 1.4118e-04
# Epoch 257/500
# 1028/1028 - 1s - loss: 1.9014e-04
# Epoch 258/500
# 1028/1028 - 1s - loss: 1.5830e-04
# Epoch 259/500
# 1028/1028 - 1s - loss: 1.3855e-04
# Epoch 260/500
# 1028/1028 - 1s - loss: 1.7547e-04
# Epoch 261/500
# 1028/1028 - 1s - loss: 1.4658e-04
# Epoch 262/500
# 1028/1028 - 1s - loss: 1.5266e-04
# Epoch 263/500
# 1028/1028 - 1s - loss: 1.7426e-04
# Epoch 264/500
# 1028/1028 - 1s - loss: 1.3842e-04
# Epoch 265/500
# 1028/1028 - 1s - loss: 1.4828e-04
# Epoch 266/500
# 1028/1028 - 1s - loss: 2.0080e-04
# Epoch 267/500
# 1028/1028 - 1s - loss: 1.6734e-04
# Epoch 268/500
# 1028/1028 - 1s - loss: 1.7115e-04
# Epoch 269/500
# 1028/1028 - 1s - loss: 1.2783e-04
# Epoch 270/500
# 1028/1028 - 1s - loss: 1.4318e-04
# Epoch 271/500
# 1028/1028 - 1s - loss: 1.6448e-04
# Epoch 272/500
# 1028/1028 - 1s - loss: 1.4284e-04
# Epoch 273/500
# 1028/1028 - 1s - loss: 1.3343e-04
# Epoch 274/500
# 1028/1028 - 1s - loss: 1.5557e-04
# Epoch 275/500
# 1028/1028 - 1s - loss: 1.5043e-04
# Epoch 276/500
# 1028/1028 - 1s - loss: 1.4256e-04
# Epoch 277/500
# 1028/1028 - 1s - loss: 1.5693e-04
# Epoch 278/500
# 1028/1028 - 1s - loss: 1.5340e-04
# Epoch 279/500
# 1028/1028 - 1s - loss: 1.4544e-04
# Epoch 280/500
# 1028/1028 - 1s - loss: 1.5925e-04
# Epoch 281/500
# 1028/1028 - 1s - loss: 1.5200e-04
# Epoch 282/500
# 1028/1028 - 1s - loss: 1.6081e-04
# Epoch 283/500
# 1028/1028 - 1s - loss: 1.4136e-04
# Epoch 284/500
# 1028/1028 - 1s - loss: 1.3724e-04
# Epoch 285/500
# 1028/1028 - 1s - loss: 1.4187e-04
# Epoch 286/500
# 1028/1028 - 1s - loss: 1.5471e-04
# Epoch 287/500
# 1028/1028 - 1s - loss: 1.5153e-04
# Epoch 288/500
# 1028/1028 - 1s - loss: 1.5160e-04
# Epoch 289/500
# 1028/1028 - 1s - loss: 1.3578e-04
# Epoch 290/500
# 1028/1028 - 1s - loss: 1.7417e-04
# Epoch 291/500
# 1028/1028 - 1s - loss: 1.3213e-04
# Epoch 292/500
# 1028/1028 - 1s - loss: 1.5170e-04
# Epoch 293/500
# 1028/1028 - 1s - loss: 1.6168e-04
# Epoch 294/500
# 1028/1028 - 1s - loss: 1.2746e-04
# Epoch 295/500
# 1028/1028 - 1s - loss: 1.3718e-04
# Epoch 296/500
# 1028/1028 - 1s - loss: 1.3879e-04
# Epoch 297/500
# 1028/1028 - 1s - loss: 1.4708e-04
# Epoch 298/500
# 1028/1028 - 1s - loss: 1.3484e-04
# Epoch 299/500
# 1028/1028 - 1s - loss: 1.3554e-04
# Epoch 300/500
# 1028/1028 - 1s - loss: 1.5324e-04
#
# Epoch 00300: saving model to models/rleg4/rleg4-saved-model-300
# INFO:tensorflow:Assets written to: models/rleg4/rleg4-saved-model-300/assets
# Epoch 301/500
# 1028/1028 - 1s - loss: 1.4081e-04
# Epoch 302/500
# 1028/1028 - 1s - loss: 1.4134e-04
# Epoch 303/500
# 1028/1028 - 1s - loss: 1.3644e-04
# Epoch 304/500
# 1028/1028 - 1s - loss: 1.2724e-04
# Epoch 305/500
# 1028/1028 - 1s - loss: 1.6347e-04
# Epoch 306/500
# 1028/1028 - 1s - loss: 1.5359e-04
# Epoch 307/500
# 1028/1028 - 1s - loss: 1.2792e-04
# Epoch 308/500
# 1028/1028 - 1s - loss: 1.3328e-04
# Epoch 309/500
# 1028/1028 - 1s - loss: 1.6563e-04
# Epoch 310/500
# 1028/1028 - 1s - loss: 1.4044e-04
# Epoch 311/500
# 1028/1028 - 1s - loss: 1.3125e-04
# Epoch 312/500
# 1028/1028 - 1s - loss: 1.3129e-04
# Epoch 313/500
# 1028/1028 - 1s - loss: 1.5373e-04
# Epoch 314/500
# 1028/1028 - 1s - loss: 1.5528e-04
# Epoch 315/500
# 1028/1028 - 1s - loss: 1.3406e-04
# Epoch 316/500
# 1028/1028 - 1s - loss: 1.2987e-04
# Epoch 317/500
# 1028/1028 - 1s - loss: 1.5293e-04
# Epoch 318/500
# 1028/1028 - 1s - loss: 1.4837e-04
# Epoch 319/500
# 1028/1028 - 1s - loss: 1.2549e-04
# Epoch 320/500
# 1028/1028 - 1s - loss: 1.3565e-04
# Epoch 321/500
# 1028/1028 - 1s - loss: 1.2210e-04
# Epoch 322/500
# 1028/1028 - 1s - loss: 1.4281e-04
# Epoch 323/500
# 1028/1028 - 1s - loss: 1.3369e-04
# Epoch 324/500
# 1028/1028 - 1s - loss: 1.4969e-04
# Epoch 325/500
# 1028/1028 - 1s - loss: 1.4357e-04
# Epoch 326/500
# 1028/1028 - 1s - loss: 1.3834e-04
# Epoch 327/500
# 1028/1028 - 1s - loss: 1.5315e-04
# Epoch 328/500
# 1028/1028 - 1s - loss: 1.2656e-04
# Epoch 329/500
# 1028/1028 - 1s - loss: 1.3467e-04
# Epoch 330/500
# 1028/1028 - 1s - loss: 1.4580e-04
# Epoch 331/500
# 1028/1028 - 1s - loss: 1.3693e-04
# Epoch 332/500
# 1028/1028 - 1s - loss: 1.1894e-04
# Epoch 333/500
# 1028/1028 - 1s - loss: 1.3423e-04
# Epoch 334/500
# 1028/1028 - 1s - loss: 1.3154e-04
# Epoch 335/500
# 1028/1028 - 1s - loss: 1.3466e-04
# Epoch 336/500
# 1028/1028 - 1s - loss: 1.3034e-04
# Epoch 337/500
# 1028/1028 - 1s - loss: 1.4977e-04
# Epoch 338/500
# 1028/1028 - 1s - loss: 1.3240e-04
# Epoch 339/500
# 1028/1028 - 1s - loss: 1.1944e-04
# Epoch 340/500
# 1028/1028 - 1s - loss: 1.3431e-04
# Epoch 341/500
# 1028/1028 - 1s - loss: 1.0951e-04
# Epoch 342/500
# 1028/1028 - 1s - loss: 1.3561e-04
# Epoch 343/500
# 1028/1028 - 1s - loss: 1.4278e-04
# Epoch 344/500
# 1028/1028 - 1s - loss: 1.1991e-04
# Epoch 345/500
# 1028/1028 - 1s - loss: 1.2768e-04
# Epoch 346/500
# 1028/1028 - 1s - loss: 1.2146e-04
# Epoch 347/500
# 1028/1028 - 1s - loss: 1.2334e-04
# Epoch 348/500
# 1028/1028 - 1s - loss: 1.0866e-04
# Epoch 349/500
# 1028/1028 - 1s - loss: 1.3190e-04
# Epoch 350/500
# 1028/1028 - 1s - loss: 1.4413e-04
#
# Epoch 00350: saving model to models/rleg4/rleg4-saved-model-350
# INFO:tensorflow:Assets written to: models/rleg4/rleg4-saved-model-350/assets
# Epoch 351/500
# 1028/1028 - 1s - loss: 1.3567e-04
# Epoch 352/500
# 1028/1028 - 1s - loss: 1.0788e-04
# Epoch 353/500
# 1028/1028 - 1s - loss: 1.2281e-04
# Epoch 354/500
# 1028/1028 - 1s - loss: 1.0969e-04
# Epoch 355/500
# 1028/1028 - 1s - loss: 1.4746e-04
# Epoch 356/500
# 1028/1028 - 1s - loss: 1.2895e-04
# Epoch 357/500
# 1028/1028 - 1s - loss: 1.1035e-04
# Epoch 358/500
# 1028/1028 - 1s - loss: 1.1402e-04
# Epoch 359/500
# 1028/1028 - 1s - loss: 1.2963e-04
# Epoch 360/500
# 1028/1028 - 1s - loss: 1.0951e-04
# Epoch 361/500
# 1028/1028 - 1s - loss: 1.4172e-04
# Epoch 362/500
# 1028/1028 - 1s - loss: 1.3115e-04
# Epoch 363/500
# 1028/1028 - 1s - loss: 1.3917e-04
# Epoch 364/500
# 1028/1028 - 1s - loss: 1.2555e-04
# Epoch 365/500
# 1028/1028 - 1s - loss: 1.1394e-04
# Epoch 366/500
# 1028/1028 - 1s - loss: 1.1944e-04
# Epoch 367/500
# 1028/1028 - 1s - loss: 1.1428e-04
# Epoch 368/500
# 1028/1028 - 1s - loss: 1.1851e-04
# Epoch 369/500
# 1028/1028 - 1s - loss: 1.4805e-04
# Epoch 370/500
# 1028/1028 - 1s - loss: 1.1898e-04
# Epoch 371/500
# 1028/1028 - 1s - loss: 1.1079e-04
# Epoch 372/500
# 1028/1028 - 1s - loss: 1.4551e-04
# Epoch 373/500
# 1028/1028 - 1s - loss: 1.3162e-04
# Epoch 374/500
# 1028/1028 - 1s - loss: 1.0684e-04
# Epoch 375/500
# 1028/1028 - 1s - loss: 1.0907e-04
# Epoch 376/500
# 1028/1028 - 1s - loss: 1.2283e-04
# Epoch 377/500
# 1028/1028 - 1s - loss: 1.3996e-04
# Epoch 378/500
# 1028/1028 - 1s - loss: 1.1605e-04
# Epoch 379/500
# 1028/1028 - 1s - loss: 1.5041e-04
# Epoch 380/500
# 1028/1028 - 1s - loss: 1.3279e-04
# Epoch 381/500
# 1028/1028 - 1s - loss: 1.2151e-04
# Epoch 382/500
# 1028/1028 - 1s - loss: 1.3696e-04
# Epoch 383/500
# 1028/1028 - 1s - loss: 1.1036e-04
# Epoch 384/500
# 1028/1028 - 1s - loss: 1.2387e-04
# Epoch 385/500
# 1028/1028 - 1s - loss: 1.1627e-04
# Epoch 386/500
# 1028/1028 - 1s - loss: 1.0799e-04
# Epoch 387/500
# 1028/1028 - 1s - loss: 1.2073e-04
# Epoch 388/500
# 1028/1028 - 1s - loss: 1.3628e-04
# Epoch 389/500
# 1028/1028 - 1s - loss: 1.0506e-04
# Epoch 390/500
# 1028/1028 - 1s - loss: 1.2809e-04
# Epoch 391/500
# 1028/1028 - 1s - loss: 1.2719e-04
# Epoch 392/500
# 1028/1028 - 1s - loss: 1.0597e-04
# Epoch 393/500
# 1028/1028 - 1s - loss: 1.2775e-04
# Epoch 394/500
# 1028/1028 - 1s - loss: 1.3026e-04
# Epoch 395/500
# 1028/1028 - 1s - loss: 1.1928e-04
# Epoch 396/500
# 1028/1028 - 1s - loss: 1.0136e-04
# Epoch 397/500
# 1028/1028 - 1s - loss: 1.3995e-04
# Epoch 398/500
# 1028/1028 - 1s - loss: 1.0342e-04
# Epoch 399/500
# 1028/1028 - 1s - loss: 1.3765e-04
# Epoch 400/500
# 1028/1028 - 1s - loss: 1.1789e-04
#
# Epoch 00400: saving model to models/rleg4/rleg4-saved-model-400
# INFO:tensorflow:Assets written to: models/rleg4/rleg4-saved-model-400/assets
# Epoch 401/500
# 1028/1028 - 1s - loss: 1.0249e-04
# Epoch 402/500
# 1028/1028 - 1s - loss: 1.4412e-04
# Epoch 403/500
# 1028/1028 - 1s - loss: 1.2156e-04
# Epoch 404/500
# 1028/1028 - 1s - loss: 1.1801e-04
# Epoch 405/500
# 1028/1028 - 1s - loss: 1.2630e-04
# Epoch 406/500
# 1028/1028 - 1s - loss: 1.2123e-04
# Epoch 407/500
# 1028/1028 - 1s - loss: 1.3365e-04
# Epoch 408/500
# 1028/1028 - 1s - loss: 1.1559e-04
# Epoch 409/500
# 1028/1028 - 1s - loss: 1.2623e-04
# Epoch 410/500
# 1028/1028 - 1s - loss: 9.7459e-05
# Epoch 411/500
# 1028/1028 - 1s - loss: 1.3269e-04
# Epoch 412/500
# 1028/1028 - 1s - loss: 1.1700e-04
# Epoch 413/500
# 1028/1028 - 1s - loss: 1.2244e-04
# Epoch 414/500
# 1028/1028 - 1s - loss: 1.1491e-04
# Epoch 415/500
# 1028/1028 - 1s - loss: 1.1334e-04
# Epoch 416/500
# 1028/1028 - 1s - loss: 1.1747e-04
# Epoch 417/500
# 1028/1028 - 1s - loss: 1.0351e-04
# Epoch 418/500
# 1028/1028 - 1s - loss: 1.1477e-04
# Epoch 419/500
# 1028/1028 - 1s - loss: 1.2571e-04
# Epoch 420/500
# 1028/1028 - 1s - loss: 9.7923e-05
# Epoch 421/500
# 1028/1028 - 1s - loss: 1.3369e-04
# Epoch 422/500
# 1028/1028 - 1s - loss: 1.2294e-04
# Epoch 423/500
# 1028/1028 - 1s - loss: 1.0091e-04
# Epoch 424/500
# 1028/1028 - 1s - loss: 1.1747e-04
# Epoch 425/500
# 1028/1028 - 1s - loss: 1.0785e-04
# Epoch 426/500
# 1028/1028 - 1s - loss: 1.1429e-04
# Epoch 427/500
# 1028/1028 - 1s - loss: 1.0848e-04
# Epoch 428/500
# 1028/1028 - 1s - loss: 1.0156e-04
# Epoch 429/500
# 1028/1028 - 1s - loss: 1.0382e-04
# Epoch 430/500
# 1028/1028 - 1s - loss: 1.4425e-04
# Epoch 431/500
# 1028/1028 - 1s - loss: 9.7665e-05
# Epoch 432/500
# 1028/1028 - 1s - loss: 1.4259e-04
# Epoch 433/500
# 1028/1028 - 1s - loss: 9.7751e-05
# Epoch 434/500
# 1028/1028 - 1s - loss: 1.2686e-04
# Epoch 435/500
# 1028/1028 - 1s - loss: 1.3387e-04
# Epoch 436/500
# 1028/1028 - 1s - loss: 9.7559e-05
# Epoch 437/500
# 1028/1028 - 1s - loss: 1.1283e-04
# Epoch 438/500
# 1028/1028 - 1s - loss: 1.0054e-04
# Epoch 439/500
# 1028/1028 - 1s - loss: 1.1119e-04
# Epoch 440/500
# 1028/1028 - 1s - loss: 1.2348e-04
# Epoch 441/500
# 1028/1028 - 1s - loss: 8.9155e-05
# Epoch 442/500
# 1028/1028 - 1s - loss: 1.2789e-04
# Epoch 443/500
# 1028/1028 - 1s - loss: 9.6446e-05
# Epoch 444/500
# 1028/1028 - 1s - loss: 1.3227e-04
# Epoch 445/500
# 1028/1028 - 1s - loss: 1.0082e-04
# Epoch 446/500
# 1028/1028 - 1s - loss: 1.0813e-04
# Epoch 447/500
# 1028/1028 - 1s - loss: 9.2982e-05
# Epoch 448/500
# 1028/1028 - 1s - loss: 1.0502e-04
# Epoch 449/500
# 1028/1028 - 1s - loss: 1.0133e-04
# Epoch 450/500
# 1028/1028 - 1s - loss: 1.0613e-04
#
# Epoch 00450: saving model to models/rleg4/rleg4-saved-model-450
# INFO:tensorflow:Assets written to: models/rleg4/rleg4-saved-model-450/assets
# Epoch 451/500
# 1028/1028 - 1s - loss: 1.0495e-04
# Epoch 452/500
# 1028/1028 - 1s - loss: 1.1134e-04
# Epoch 453/500
# 1028/1028 - 1s - loss: 1.0883e-04
# Epoch 454/500
# 1028/1028 - 1s - loss: 1.0471e-04
# Epoch 455/500
# 1028/1028 - 1s - loss: 9.7844e-05
# Epoch 456/500
# 1028/1028 - 1s - loss: 1.1575e-04
# Epoch 457/500
# 1028/1028 - 1s - loss: 1.0295e-04
# Epoch 458/500
# 1028/1028 - 1s - loss: 1.1183e-04
# Epoch 459/500
# 1028/1028 - 1s - loss: 1.2756e-04
# Epoch 460/500
# 1028/1028 - 1s - loss: 1.0350e-04
# Epoch 461/500
# 1028/1028 - 1s - loss: 1.0342e-04
# Epoch 462/500
# 1028/1028 - 1s - loss: 1.0417e-04
# Epoch 463/500
# 1028/1028 - 1s - loss: 1.1277e-04
# Epoch 464/500
# 1028/1028 - 1s - loss: 1.1404e-04
# Epoch 465/500
# 1028/1028 - 1s - loss: 1.1045e-04
# Epoch 466/500
# 1028/1028 - 1s - loss: 8.8448e-05
# Epoch 467/500
# 1028/1028 - 1s - loss: 9.7123e-05
# Epoch 468/500
# 1028/1028 - 1s - loss: 1.0610e-04
# Epoch 469/500
# 1028/1028 - 1s - loss: 1.0797e-04
# Epoch 470/500
# 1028/1028 - 1s - loss: 1.2803e-04
# Epoch 471/500
# 1028/1028 - 1s - loss: 1.0602e-04
# Epoch 472/500
# 1028/1028 - 1s - loss: 1.0470e-04
# Epoch 473/500
# 1028/1028 - 1s - loss: 1.1615e-04
# Epoch 474/500
# 1028/1028 - 1s - loss: 1.0134e-04
# Epoch 475/500
# 1028/1028 - 1s - loss: 1.1707e-04
# Epoch 476/500
# 1028/1028 - 1s - loss: 9.6204e-05
# Epoch 477/500
# 1028/1028 - 1s - loss: 1.0898e-04
# Epoch 478/500
# 1028/1028 - 1s - loss: 1.1663e-04
# Epoch 479/500
# 1028/1028 - 1s - loss: 8.6999e-05
# Epoch 480/500
# 1028/1028 - 1s - loss: 1.2006e-04
# Epoch 481/500
# 1028/1028 - 1s - loss: 8.7117e-05
# Epoch 482/500
# 1028/1028 - 1s - loss: 1.0733e-04
# Epoch 483/500
# 1028/1028 - 1s - loss: 1.0618e-04
# Epoch 484/500
# 1028/1028 - 1s - loss: 1.1519e-04
# Epoch 485/500
# 1028/1028 - 1s - loss: 1.0540e-04
# Epoch 486/500
# 1028/1028 - 1s - loss: 1.0888e-04
# Epoch 487/500
# 1028/1028 - 1s - loss: 1.0800e-04
# Epoch 488/500
# 1028/1028 - 1s - loss: 9.4340e-05
# Epoch 489/500
# 1028/1028 - 1s - loss: 1.0192e-04
# Epoch 490/500
# 1028/1028 - 1s - loss: 1.1613e-04
# Epoch 491/500
# 1028/1028 - 1s - loss: 9.8173e-05
# Epoch 492/500
# 1028/1028 - 1s - loss: 9.4087e-05
# Epoch 493/500
# 1028/1028 - 1s - loss: 9.9584e-05
# Epoch 494/500
# 1028/1028 - 1s - loss: 1.0944e-04
# Epoch 495/500
# 1028/1028 - 1s - loss: 9.8703e-05
# Epoch 496/500
# 1028/1028 - 1s - loss: 9.8885e-05
# Epoch 497/500
# 1028/1028 - 1s - loss: 9.2222e-05
# Epoch 498/500
# 1028/1028 - 1s - loss: 9.7948e-05
# Epoch 499/500
# 1028/1028 - 1s - loss: 1.0546e-04
# Epoch 500/500
# 1028/1028 - 1s - loss: 9.3522e-05
#
# Epoch 00500: saving model to models/rleg4/rleg4-saved-model-500
# INFO:tensorflow:Assets written to: models/rleg4/rleg4-saved-model-500/assets

# %%
yhat = model.predict(x)
print(yhat)
# Out:
# [[0.52509314]
#  [0.52509516]
#  [0.52509713]
#  ...
#  [0.53450245]
#  [0.5345191 ]
#  [0.5345353 ]]

# %%
x_plot = scale_x.inverse_transform(x)
y_plot = scale_y.inverse_transform(y)
yhat_plot = scale_y.inverse_transform(yhat)

# %%
import math
a = mean_squared_error(y_plot, yhat_plot)
print(math.sqrt(a))
# Out:
# 105.49774875766269

# %%
  fig, axs = plt.subplots(1)
  fig.set_size_inches(10, 6, forward=True)    
  axs.plot(rleg4_angle, 'b')
  axs.set_title('rleg4_angle')
  axs.plot(yhat_plot, 'r')

# %%
print(history.history.keys())
# Out:
# dict_keys(['loss'])
